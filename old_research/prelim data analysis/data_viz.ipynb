# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Read the file, there was a syntax issue on line 10405

# %%
df = pd.read_csv("../All Earthquakes.csv")
df
# Out:
#              No.         Orgin date  Longitude(E)  Latitude(N)  Magnitude  \
# 0      Small area   2025-02-12 0:09       121.942      24.3840        3.8
# 1              64  2025-02-11 22:04       121.665      24.1742        4.0
# 2      Small area  2025-02-11 20:46       120.459      23.5483        3.2
# 3              63  2025-02-11 15:52       120.496      23.2458        4.1
# 4      Small area  2025-02-11 15:45       120.505      23.2862        3.6
# ...           ...               ...           ...          ...        ...
# 15961           5   1997-01-16 9:07       121.300      22.0100        5.4
# 15962           4  1997-01-09 17:08       121.530      22.9300        4.1
# 15963           3  1997-01-08 20:14       121.380      22.7900        4.1
# 15964           2  1997-01-05 18:34       122.530      24.6200        5.8
# 15965           1  1997-01-02 14:31       121.090      22.4200        4.7
#
#        Depth        Location  \
# 0       24.3  24.38N 121.94E
# ...

# %%
# pull out var
size = df['Magnitude'] ** 3  # magnitude beign exponential for intensity 
lat = df['Longitude(E)']
long = df['Latitude(N)']

# Create a scatter plot
plt.figure(figsize=(10, 6))
scatter = plt.scatter(
    lat, 
    long, 
    s=size,  
    c=df['Depth'],           # depth color
    cmap='viridis',          # color palette
    alpha=0.2,               # transparency
    edgecolor='k'            # edge color for better visibility
)

# Add colorbar
cbar = plt.colorbar(scatter)
cbar.set_label('Depth (km)')

# Add labels and title
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Earthquake Visualization: Size (Magnitude) and Color (Depth)')

# Show the plot
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
#
# NameError                                 Traceback (most recent call last)
#
# Cell In[23], line 14
#
#      11 values = depth_grid.ravel()
#
#      13 # Interpolate using cubic interpolation
#
# ---> 14 depth_cont = griddata(points, values, (lat_cont_grid, lon_cont_grid), method='cubic')
#
#      16 plt.figure(figsize=(10, 6))
#
#      17 contour = plt.contourf(lon_cont_grid, lat_cont_grid, depth_cont, cmap='viridis', levels=50)
#
#
#
# NameError: name 'griddata' is not defined
