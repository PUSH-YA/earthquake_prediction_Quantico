# %%
import matplotlib.pyplot as plt 
import pandas as pd 
import numpy as np
OUTPUTS_DIR = './results_multivariate/Gaussian'

# %%
state0= {'InterEventTime': np.float64(-0.004467759983455944), 'Depth': np.float64(0.6351719255052863), 'Magnitude': np.float64(0.42061284892340917), 'TimeSinceMag65': np.float64(-0.4613943548386162), 'Energy': np.float64(-0.056961628507831714), 'DistanceFromRef': np.float64(0.6467891082145423)}
state1= {'InterEventTime': np.float64(-0.25843195796979385), 'Depth': np.float64(0.11765163315992137), 'Magnitude': np.float64(1.5519314369185384), 'TimeSinceMag65': np.float64(-0.43606597966013383), 'Energy': np.float64(-0.03283591856795543), 'DistanceFromRef': np.float64(0.5887663505608682)}
state2= {'InterEventTime': np.float64(-0.627761424363891), 'Depth': np.float64(-0.497815259709904), 'Magnitude': np.float64(-0.5086950215410085), 'TimeSinceMag65': np.float64(1.2649850280776043), 'Energy': np.float64(-0.058357432652621104), 'DistanceFromRef': np.float64(-0.5401840565123013)}
state3= {'InterEventTime': np.float64(0.2398178428159689), 'Depth': np.float64(-0.32537482929841205), 'Magnitude': np.float64(-0.6122984491218569), 'TimeSinceMag65': np.float64(-0.4099695101783993), 'Energy': np.float64(-0.058937640823583735), 'DistanceFromRef': np.float64(-0.19878592799280861)}
state4= {'InterEventTime': np.float64(0.6078556702385138), 'Depth': np.float64(2.4014400254998), 'Magnitude': np.float64(3.258298615768218), 'TimeSinceMag65': np.float64(0.35119319225255496), 'Energy': np.float64(4.275432852704405), 'DistanceFromRef': np.float64(1.349278358685868)}
state5= {'InterEventTime': np.float64(2.210890693270474), 'Depth': np.float64(1.4829286793719871), 'Magnitude': np.float64(0.7012644846947164), 'TimeSinceMag65': np.float64(-0.433936063663601), 'Energy': np.float64(-0.051767946269851955), 'DistanceFromRef': np.float64(0.03932316376855049)}
state6= {'InterEventTime': np.float64(-0.6244915204872774), 'Depth': np.float64(-0.3546101251048107), 'Magnitude': np.float64(-0.24703545355453968), 'TimeSinceMag65': np.float64(-0.4673489934599353), 'Energy': np.float64(-0.05817357799355614), 'DistanceFromRef': np.float64(-0.11048783755317663)}
state7= {'InterEventTime': np.float64(0.09753442134007263), 'Depth': np.float64(0.9591487199269494), 'Magnitude': np.float64(1.7400431441200033), 'TimeSinceMag65': np.float64(1.5548308144182486), 'Energy': np.float64(-0.010004564265459343), 'DistanceFromRef': np.float64(0.4665006107660072)}
state8= {'InterEventTime': np.float64(0.9519323593272935), 'Depth': np.float64(0.7201156506234863), 'Magnitude': np.float64(0.31693176580445803), 'TimeSinceMag65': np.float64(1.8031952125935997), 'Energy': np.float64(-0.056605090410032484), 'DistanceFromRef': np.float64(0.18393474533968523)}
state9= {'InterEventTime': np.float64(0.025809181485445663), 'Depth': np.float64(1.751880101959896), 'Magnitude': np.float64(2.2765499021444473), 'TimeSinceMag65': np.float64(-0.4734336817068607), 'Energy': np.float64(0.13369247414087487), 'DistanceFromRef': np.float64(1.0782533654285502)}
state10= {'InterEventTime': np.float64(-0.022904551881277328), 'Depth': np.float64(-0.31123318022013396), 'Magnitude': np.float64(-0.6378818539949656), 'TimeSinceMag65': np.float64(1.248393053621039), 'Energy': np.float64(-0.0588762461108491), 'DistanceFromRef': np.float64(-0.07162063513118469)}

# %%
# Collect all state dictionaries into a list
states = [state0, state1, state2, state3, state4, state5, state6, state7, state8, state9, state10]

# Create a DataFrame where each row is a state
df_states = pd.DataFrame(states)

# Plot each feature as a time series across states
df_states.plot(marker='o')
plt.xlabel('State')
plt.ylabel('Feature Value')
plt.title('Time Series of Features Across States')
plt.legend(loc='best')
plt.savefig(f"{OUTPUTS_DIR}/features_vs_states_line.png")
plt.show()
